# %% [markdown]
# <a href="https://colab.research.google.com/github/ChristianaKiervin/MachineLearning_GirlScriptScholarship/blob/main/EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# `Exploratory Data Analysis`
#
# [Link to Download the dataset](https://archive.ics.uci.edu/ml/datasets/Student+Performance)
#
# **Date Created**: May 30, 2021
#
#
# **Author**:
#  Shivani Shimpi
#
#
# **Modified By**:
# Christiana Kiervin
#
#
# Written as part of instruction during a live code session.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd '/content/drive/MyDrive/ML Course/student'
# Out:
# /content/drive/MyDrive/ML Course/student

# %%
ls
# Out:
# student-mat.csv  student-merge.R  student-por.csv  student.txt

# %%
import pandas as pd  #for csv or excel data
import numpy as np  #for numbers/arrays/tensors
import tensorflow as tf  #framework
from tensorflow import keras #api
import os  #using os commands between python language

# %% [markdown]
# Pandas has a method to load in csv and excel type data. Save it into a variable.
#
# If it were excel it would just be read_excel.
#
# Use the appropriate separator.

# %%
mathData = pd.read_csv('student-mat.csv', sep=';') #load the csv file as dataframe

# %% [markdown]
# .head specifies that we're accessing the first 10 columns.
#
#
# .tail(num) would access the last num columns

# %%
mathData.head(10) #print the first ten rows of the dataframe
# Out:
#   school sex  age address famsize Pstatus  ...  Walc  health absences  G1  G2  G3
# 0     GP   F   18       U     GT3       A  ...     1       3        6   5   6   6
# 1     GP   F   17       U     GT3       T  ...     1       3        4   5   5   6
# 2     GP   F   15       U     LE3       T  ...     3       3       10   7   8  10
# 3     GP   F   15       U     GT3       T  ...     1       5        2  15  14  15
# 4     GP   F   16       U     GT3       T  ...     2       5        4   6  10  10
# 5     GP   M   16       U     LE3       T  ...     2       5       10  15  15  15
# 6     GP   M   16       U     LE3       T  ...     1       3        0  12  12  11
# 7     GP   F   17       U     GT3       A  ...     1       1        6   6   5   6
# 8     GP   M   15       U     LE3       A  ...     1       1        0  16  18  19
# 9     GP   M   15       U     GT3       T  ...     1       5        0  14  15  15
#
# [10 rows x 33 columns]

# %% [markdown]
# ## Data Processing
#
#
# Categorical to numeric value conversion

# %% [markdown]
# The unique keyword:
#
#  variable.column.unique --> takes all {column} values from the {variable} dataframe and prints out the unique ones.

# %%
#unique classes/categories in every column 

print(f'school: {mathData.school.unique()}')
print(f'sex: {mathData.sex.unique()}')
print(f'address: {mathData.address.unique()}')
print(f'Mjob: {mathData.Mjob.unique()}')
print(f'Fjob: {mathData.Fjob.unique()}')
print(f'higher: {mathData.higher.unique()}')
# Out:
# school: ['GP' 'MS']
# sex: ['F' 'M']
# address: ['U' 'R']
# Mjob: ['at_home' 'health' 'other' 'services' 'teacher']
# Fjob: ['teacher' 'other' 'services' 'health' 'at_home']
# higher: ['yes' 'no']

# %% [markdown]
# To convert:
#
# access the column `school` from the variable `mathData` which has the pandas dataframe.
#
# Once we access it, we're using a dictionary. Since we're using a dictionary we can replace the literal strings with numeric data.
#
# Meaning -->
# * Replace `GP` with 1
# *   Replace `MS` with 2 (and so on)

# %%
#convert the categories into numbers 

#binary valued
mathData['school'] = mathData['school'].apply({'GP':1, 'MS':2}.get)
mathData['sex'] = mathData['sex'].apply({'F':1, 'M':2}.get)
mathData['address'] = mathData['address'].apply({'U':1, 'R':2}.get)
mathData['higher'] = mathData['higher'].apply({'yes':1, 'no':2}.get)


#multi-valued
mathData['Mjob'] = mathData['Mjob'].apply({'at_home':1, 'health':2, 'other':3, 'services':4, 'teacher':5}.get)
mathData['Fjob'] = mathData['Fjob'].apply({'at_home':1, 'health':2, 'other':3, 'services':4, 'teacher':5}.get)

mathData.head(15)
# Out:
#     school  sex  age  address famsize  ... health  absences  G1  G2  G3
# 0        1    1   18        1     GT3  ...      3         6   5   6   6
# 1        1    1   17        1     GT3  ...      3         4   5   5   6
# 2        1    1   15        1     LE3  ...      3        10   7   8  10
# 3        1    1   15        1     GT3  ...      5         2  15  14  15
# 4        1    1   16        1     GT3  ...      5         4   6  10  10
# 5        1    2   16        1     LE3  ...      5        10  15  15  15
# 6        1    2   16        1     LE3  ...      3         0  12  12  11
# 7        1    1   17        1     GT3  ...      1         6   6   5   6
# 8        1    2   15        1     LE3  ...      1         0  16  18  19
# 9        1    2   15        1     GT3  ...      5         0  14  15  15
# 10       1    1   15        1     GT3  ...      2         0  10   8   9
# 11       1    1   15        1     GT3  ...      4         4  10  12  12
# ...
